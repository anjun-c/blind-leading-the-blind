# %% [markdown]
# # 📖 Introduction

# %% [markdown]
# The goal of this project is to develop a deep learning model that can accurately classify facial expressions into one of seven categories: Angry, Disgust, Fear, Happy, Sad, Surprise, and Neutral. We will use convolutional neural networks (CNNs) to train our model, as they have been shown to be effective in image classification tasks. Our approach involves training a CNN model from scratch on the FER-2013 dataset
#
# ![emotions.png](attachment:02a21be9-12eb-4595-a450-8414036bac30.png)

# %% [markdown]
# # 💾 Data

# %% [markdown]
# The FER-2013 dataset consists of 48x48 pixel grayscale images of faces that have been automatically registered to be centred and occupy a similar amount of space in each image. The dataset contains 24,400 images, with 22,968 examples in the training set and 1,432 examples in the public test set.

# %% [markdown]
# # 🛠 Preprocessing

# %% [markdown]
# In this section, we will be using both data generators and data augmentation to train a deep learning model for human emotion detection using the FER-2013 dataset. Due to the size and complexity of the dataset, it would be impractical to load all of the images into memory at once. Therefore, we will be using data generators to generate batches of images on-the-fly during training, which will allow us to efficiently train our model on the entire dataset.
#
# In addition, we will be applying various data augmentation techniques to the training images, such as rotation, shifting, and flipping. This will help to increase the size and diversity of our training set, which can improve the performance of our deep learning model. By introducing variability into the training process, data augmentation can also help to prevent overfitting, which occurs when the model becomes too closely tailored to the training set and performs poorly on new, unseen data.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = "../data/fer2013/train" # Directory containing the training data
test_dir = "../data/fer2013/test"  # Directory containing the validation data

# %%
train_datagen = ImageDataGenerator(
    width_shift_range = 0.1,        # Randomly shift the width of images by up to 10%
    height_shift_range = 0.1,       # Randomly shift the height of images by up to 10%
    horizontal_flip = True,         # Flip images horizontally at random
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

validation_datagen = ImageDataGenerator(
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

# %%
train_generator = train_datagen.flow_from_directory(
    directory = train_dir,           # Directory containing the training data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "training"              # Uses the training subset of the data
)

validation_generator = validation_datagen.flow_from_directory(
    directory = test_dir,            # Directory containing the validation data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "validation"            # Uses the validation subset of the data
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %% [markdown]
# # Modeling

# %% [markdown]
# ## CNN Model

# %% [markdown]
# To develop the CNN architecture, we will begin by defining the input layer and the number of filters in the first convolutional layer. Then, we will add additional convolutional layers with increasing numbers of filters, followed by max-pooling layers to reduce the spatial dimensions of the feature maps. After the convolutional layers, we will add fully connected layers with ReLU activation to classify the emotions.
#
# We will experiment with different numbers of convolutional layers, filter sizes, and fully connected layers to optimize the model performance. Additionally, we will use techniques such as dropout and batch normalization to prevent overfitting and improve the generalization capability of the model.

# %%
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
import tensorflow as tf 

# Define the model architecture
model = Sequential()

# Add a convolutional layer with 32 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
# Add a batch normalization layer
model.add(BatchNormalization())
# Add a second convolutional layer with 64 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# Add a second batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a third convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a third batch normalization layer
model.add(BatchNormalization())
# Add a fourth convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a fourth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a fifth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a fifth batch normalization layer
model.add(BatchNormalization())
# Add a sixth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a sixth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Flatten the output of the convolutional layers
model.add(Flatten())
# Add a dense layer with 256 neurons and relu activation function
model.add(Dense(256, activation='relu'))
# Add a seventh batch normalization layer
model.add(BatchNormalization())
# Add a dropout layer with 0.5 dropout rate
model.add(Dropout(0.5))
# Add a dense layer with 7 neurons (one for each class) and softmax activation function
model.add(Dense(7, activation='softmax'))

# Compile the model with categorical cross-entropy loss, adam optimizer, and accuracy metric
model.compile(loss="categorical_crossentropy", optimizer= tf.keras.optimizers.Adam(learning_rate=0.0001), metrics=['accuracy'])

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
print("Is TensorFlow using GPU?", tf.test.is_built_with_cuda())

# List available GPUs
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print("Available GPU(s):", gpus)
else:
    print("No GPU detected, training will run on CPU.")
# Out:
# Num GPUs Available: 1
# Is TensorFlow using GPU? True
# Available GPU(s): [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# Define the callback
checkpoint_callback = ModelCheckpoint(
    filepath='model_weights.weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

# Train the model with the callback
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[checkpoint_callback]
)
# Out:
# Physical devices cannot be modified after being initialized
# Epoch 1/50
# 359/359 [==============================] - ETA: 0s - loss: 2.7685 - accuracy: 0.1849
# Epoch 1: val_accuracy improved from -inf to 0.24791, saving model to model_weights.weights.h5
# 359/359 [==============================] - 20s 55ms/step - loss: 2.7685 - accuracy: 0.1849 - val_loss: 1.9574 - val_accuracy: 0.2479
# Epoch 2/50
# 359/359 [==============================] - ETA: 0s - loss: 2.3963 - accuracy: 0.2271
# Epoch 2: val_accuracy improved from 0.24791 to 0.30517, saving model to model_weights.weights.h5
# 359/359 [==============================] - 13s 36ms/step - loss: 2.3963 - accuracy: 0.2271 - val_loss: 1.8002 - val_accuracy: 0.3052
# Epoch 3/50
# 358/359 [============================>.] - ETA: 0s - loss: 2.1904 - accuracy: 0.2671
# Epoch 3: val_accuracy improved from 0.30517 to 0.33939, saving model to model_weights.weights.h5
# 359/359 [==============================] - 14s 38ms/step - loss: 2.1901 - accuracy: 0.2672 - val_loss: 1.6877 - val_accuracy: 0.3394
# Epoch 4/50
# 359/359 [==============================] - ETA: 0s - loss: 2.0446 - accuracy: 0.3027
# Epoch 4: val_accuracy improved from 0.33939 to 0.37640, saving model to model_weights.weights.h5
# 359/359 [==============================] - 14s 39ms/step - loss: 2.0446 - accuracy: 0.3027 - val_loss: 1.6875 - val_accuracy: 0.3764
# Epoch 5/50
# 359/359 [==============================] - ETA: 0s - loss: 1.9516 - accuracy: 0.3201
# Epoch 5: val_accuracy improved from 0.37640 to 0.40782, saving model to model_weights.weights.h5
# 359/359 [==============================] - 16s 45ms/step - loss: 1.9516 - accuracy: 0.3201 - val_loss: 1.5668 - val_accuracy: 0.4078
# Epoch 6/50
# 359/359 [==============================] - ETA: 0s - loss: 1.8600 - accuracy: 0.3410
# Epoch 6: val_accuracy improved from 0.40782 to 0.41969, saving model to model_weights.weights.h5
# 359/359 [==============================] - 27s 76ms/step - loss: 1.8600 - accuracy: 0.3410 - val_loss: 1.5555 - val_accuracy: 0.4197
# Epoch 7/50
# 359/359 [==============================] - ETA: 0s - loss: 1.7968 - accuracy: 0.3549
# Epoch 7: val_accuracy improved from 0.41969 to 0.43506, saving model to model_weights.weights.h5
# 359/359 [==============================] - 25s 69ms/step - loss: 1.7968 - accuracy: 0.3549 - val_loss: 1.5337 - val_accuracy: 0.4351
# Epoch 8/50
# 359/359 [==============================] - ETA: 0s - loss: 1.7215 - accuracy: 0.3732
# Epoch 8: val_accuracy improved from 0.43506 to 0.47556, saving model to model_weights.weights.h5
# 359/359 [==============================] - 25s 69ms/step - loss: 1.7215 - accuracy: 0.3732 - val_loss: 1.4053 - val_accuracy: 0.4756
# Epoch 9/50
# 359/359 [==============================] - ETA: 0s - loss: 1.6697 - accuracy: 0.3933
# Epoch 9: val_accuracy did not improve from 0.47556
# 359/359 [==============================] - 28s 77ms/step - loss: 1.6697 - accuracy: 0.3933 - val_loss: 1.3874 - val_accuracy: 0.4693
# Epoch 10/50
# 359/359 [==============================] - ETA: 0s - loss: 1.6131 - accuracy: 0.4060
# Epoch 10: val_accuracy did not improve from 0.47556
# 359/359 [==============================] - 27s 74ms/step - loss: 1.6131 - accuracy: 0.4060 - val_loss: 1.4272 - val_accuracy: 0.4728
# Epoch 11/50
# 359/359 [==============================] - ETA: 0s - loss: 1.5566 - accuracy: 0.4245
# Epoch 11: val_accuracy improved from 0.47556 to 0.50349, saving model to model_weights.weights.h5
# 359/359 [==============================] - 25s 70ms/step - loss: 1.5566 - accuracy: 0.4245 - val_loss: 1.3377 - val_accuracy: 0.5035
# Epoch 12/50
# 359/359 [==============================] - ETA: 0s - loss: 1.5170 - accuracy: 0.4326
# Epoch 12: val_accuracy improved from 0.50349 to 0.51816, saving model to model_weights.weights.h5
# 359/359 [==============================] - 25s 70ms/step - loss: 1.5170 - accuracy: 0.4326 - val_loss: 1.2749 - val_accuracy: 0.5182
# Epoch 13/50
# 359/359 [==============================] - ETA: 0s - loss: 1.4724 - accuracy: 0.4509
# Epoch 13: val_accuracy improved from 0.51816 to 0.53142, saving model to model_weights.weights.h5
# 359/359 [==============================] - 25s 69ms/step - loss: 1.4724 - accuracy: 0.4509 - val_loss: 1.2553 - val_accuracy: 0.5314
# Epoch 14/50
# 359/359 [==============================] - ETA: 0s - loss: 1.4333 - accuracy: 0.4656
# Epoch 14: val_accuracy improved from 0.53142 to 0.54399, saving model to model_weights.weights.h5
# 359/359 [==============================] - 22s 61ms/step - loss: 1.4333 - accuracy: 0.4656 - val_loss: 1.2232 - val_accuracy: 0.5440
# Epoch 15/50
# 359/359 [==============================] - ETA: 0s - loss: 1.4020 - accuracy: 0.4720
# Epoch 15: val_accuracy improved from 0.54399 to 0.56564, saving model to model_weights.weights.h5
# 359/359 [==============================] - 22s 62ms/step - loss: 1.4020 - accuracy: 0.4720 - val_loss: 1.1789 - val_accuracy: 0.5656
# Epoch 16/50
# 359/359 [==============================] - ETA: 0s - loss: 1.3679 - accuracy: 0.4852
# Epoch 16: val_accuracy did not improve from 0.56564
# 359/359 [==============================] - 41s 114ms/step - loss: 1.3679 - accuracy: 0.4852 - val_loss: 1.1768 - val_accuracy: 0.5531
# Epoch 17/50
# 359/359 [==============================] - ETA: 0s - loss: 1.3460 - accuracy: 0.4898
# Epoch 17: val_accuracy did not improve from 0.56564
# 359/359 [==============================] - 37s 103ms/step - loss: 1.3460 - accuracy: 0.4898 - val_loss: 1.1575 - val_accuracy: 0.5580
# Epoch 18/50
# 359/359 [==============================] - ETA: 0s - loss: 1.3110 - accuracy: 0.5033
# Epoch 18: val_accuracy improved from 0.56564 to 0.56704, saving model to model_weights.weights.h5
# 359/359 [==============================] - 37s 102ms/step - loss: 1.3110 - accuracy: 0.5033 - val_loss: 1.1339 - val_accuracy: 0.5670
# Epoch 19/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2819 - accuracy: 0.5147
# Epoch 19: val_accuracy improved from 0.56704 to 0.57472, saving model to model_weights.weights.h5
# 359/359 [==============================] - 36s 102ms/step - loss: 1.2819 - accuracy: 0.5147 - val_loss: 1.1132 - val_accuracy: 0.5747
# Epoch 20/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2722 - accuracy: 0.5225
# Epoch 20: val_accuracy improved from 0.57472 to 0.57751, saving model to model_weights.weights.h5
# 359/359 [==============================] - 38s 106ms/step - loss: 1.2722 - accuracy: 0.5225 - val_loss: 1.1289 - val_accuracy: 0.5775
# Epoch 21/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2558 - accuracy: 0.5271
# Epoch 21: val_accuracy did not improve from 0.57751
# 359/359 [==============================] - 37s 103ms/step - loss: 1.2558 - accuracy: 0.5271 - val_loss: 1.1129 - val_accuracy: 0.5747
# Epoch 22/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2310 - accuracy: 0.5343
# Epoch 22: val_accuracy improved from 0.57751 to 0.57891, saving model to model_weights.weights.h5
# 359/359 [==============================] - 37s 102ms/step - loss: 1.2310 - accuracy: 0.5343 - val_loss: 1.1058 - val_accuracy: 0.5789
# Epoch 23/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2205 - accuracy: 0.5424
# Epoch 23: val_accuracy improved from 0.57891 to 0.58589, saving model to model_weights.weights.h5
# 359/359 [==============================] - 36s 100ms/step - loss: 1.2205 - accuracy: 0.5424 - val_loss: 1.0934 - val_accuracy: 0.5859
# Epoch 24/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2028 - accuracy: 0.5492
# Epoch 24: val_accuracy improved from 0.58589 to 0.59008, saving model to model_weights.weights.h5
# 359/359 [==============================] - 37s 102ms/step - loss: 1.2028 - accuracy: 0.5492 - val_loss: 1.0876 - val_accuracy: 0.5901
# Epoch 25/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1792 - accuracy: 0.5608
# Epoch 25: val_accuracy improved from 0.59008 to 0.59637, saving model to model_weights.weights.h5
# 359/359 [==============================] - 39s 108ms/step - loss: 1.1792 - accuracy: 0.5608 - val_loss: 1.0697 - val_accuracy: 0.5964
# Epoch 26/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1749 - accuracy: 0.5580
# Epoch 26: val_accuracy improved from 0.59637 to 0.60056, saving model to model_weights.weights.h5
# 359/359 [==============================] - 37s 104ms/step - loss: 1.1749 - accuracy: 0.5580 - val_loss: 1.0726 - val_accuracy: 0.6006
# Epoch 27/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1634 - accuracy: 0.5640
# Epoch 27: val_accuracy did not improve from 0.60056
# 359/359 [==============================] - 37s 102ms/step - loss: 1.1634 - accuracy: 0.5640 - val_loss: 1.0976 - val_accuracy: 0.5817
# Epoch 28/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1515 - accuracy: 0.5667
# Epoch 28: val_accuracy improved from 0.60056 to 0.60126, saving model to model_weights.weights.h5
# 359/359 [==============================] - 40s 110ms/step - loss: 1.1515 - accuracy: 0.5667 - val_loss: 1.0606 - val_accuracy: 0.6013
# Epoch 29/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1352 - accuracy: 0.5728
# Epoch 29: val_accuracy improved from 0.60126 to 0.60754, saving model to model_weights.weights.h5
# 359/359 [==============================] - 38s 105ms/step - loss: 1.1352 - accuracy: 0.5728 - val_loss: 1.0402 - val_accuracy: 0.6075
# Epoch 30/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1247 - accuracy: 0.5761
# Epoch 30: val_accuracy improved from 0.60754 to 0.60894, saving model to model_weights.weights.h5
# 359/359 [==============================] - 38s 104ms/step - loss: 1.1247 - accuracy: 0.5761 - val_loss: 1.0433 - val_accuracy: 0.6089
# Epoch 31/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1169 - accuracy: 0.5805
# Epoch 31: val_accuracy did not improve from 0.60894
# 359/359 [==============================] - 39s 109ms/step - loss: 1.1169 - accuracy: 0.5805 - val_loss: 1.0346 - val_accuracy: 0.6075
# Epoch 32/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1163 - accuracy: 0.5797
# Epoch 32: val_accuracy improved from 0.60894 to 0.61941, saving model to model_weights.weights.h5
# 359/359 [==============================] - 40s 110ms/step - loss: 1.1163 - accuracy: 0.5797 - val_loss: 1.0154 - val_accuracy: 0.6194
# Epoch 33/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0978 - accuracy: 0.5879
# Epoch 33: val_accuracy did not improve from 0.61941
# 359/359 [==============================] - 39s 109ms/step - loss: 1.0978 - accuracy: 0.5879 - val_loss: 1.0146 - val_accuracy: 0.6159
# Epoch 34/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0879 - accuracy: 0.5910
# Epoch 34: val_accuracy did not improve from 0.61941
# 359/359 [==============================] - 40s 110ms/step - loss: 1.0879 - accuracy: 0.5910 - val_loss: 1.0247 - val_accuracy: 0.6166
# Epoch 35/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0726 - accuracy: 0.5968
# Epoch 35: val_accuracy did not improve from 0.61941
# 359/359 [==============================] - 38s 105ms/step - loss: 1.0726 - accuracy: 0.5968 - val_loss: 1.0090 - val_accuracy: 0.6152
# Epoch 36/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0715 - accuracy: 0.5982
# Epoch 36: val_accuracy improved from 0.61941 to 0.62151, saving model to model_weights.weights.h5
# 359/359 [==============================] - 37s 102ms/step - loss: 1.0715 - accuracy: 0.5982 - val_loss: 0.9922 - val_accuracy: 0.6215
# Epoch 37/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0620 - accuracy: 0.6022
# Epoch 37: val_accuracy did not improve from 0.62151
# 359/359 [==============================] - 36s 101ms/step - loss: 1.0620 - accuracy: 0.6022 - val_loss: 0.9943 - val_accuracy: 0.6215
# Epoch 38/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0589 - accuracy: 0.6012
# Epoch 38: val_accuracy improved from 0.62151 to 0.62849, saving model to model_weights.weights.h5
# 359/359 [==============================] - 36s 101ms/step - loss: 1.0589 - accuracy: 0.6012 - val_loss: 0.9672 - val_accuracy: 0.6285
# Epoch 39/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0537 - accuracy: 0.6044
# Epoch 39: val_accuracy improved from 0.62849 to 0.63966, saving model to model_weights.weights.h5
# 359/359 [==============================] - 38s 104ms/step - loss: 1.0537 - accuracy: 0.6044 - val_loss: 0.9676 - val_accuracy: 0.6397
# Epoch 40/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0409 - accuracy: 0.6125
# Epoch 40: val_accuracy improved from 0.63966 to 0.64665, saving model to model_weights.weights.h5
# 359/359 [==============================] - 41s 114ms/step - loss: 1.0409 - accuracy: 0.6125 - val_loss: 0.9797 - val_accuracy: 0.6466
# Epoch 41/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0415 - accuracy: 0.6095
# Epoch 41: val_accuracy did not improve from 0.64665
# 359/359 [==============================] - 40s 111ms/step - loss: 1.0415 - accuracy: 0.6095 - val_loss: 0.9761 - val_accuracy: 0.6327
# Epoch 42/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0381 - accuracy: 0.6102
# Epoch 42: val_accuracy did not improve from 0.64665
# 359/359 [==============================] - 41s 113ms/step - loss: 1.0381 - accuracy: 0.6102 - val_loss: 0.9761 - val_accuracy: 0.6257
# Epoch 43/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0170 - accuracy: 0.6170
# Epoch 43: val_accuracy did not improve from 0.64665
# 359/359 [==============================] - 38s 105ms/step - loss: 1.0170 - accuracy: 0.6170 - val_loss: 0.9560 - val_accuracy: 0.6383
# Epoch 44/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0178 - accuracy: 0.6216
# Epoch 44: val_accuracy did not improve from 0.64665
# 359/359 [==============================] - 38s 106ms/step - loss: 1.0178 - accuracy: 0.6216 - val_loss: 0.9692 - val_accuracy: 0.6369
# Epoch 45/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0100 - accuracy: 0.6193
# Epoch 45: val_accuracy did not improve from 0.64665
# 359/359 [==============================] - 37s 104ms/step - loss: 1.0100 - accuracy: 0.6193 - val_loss: 0.9789 - val_accuracy: 0.6355
# Epoch 46/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0029 - accuracy: 0.6263
# Epoch 46: val_accuracy improved from 0.64665 to 0.65014, saving model to model_weights.weights.h5
# 359/359 [==============================] - 37s 103ms/step - loss: 1.0029 - accuracy: 0.6263 - val_loss: 0.9437 - val_accuracy: 0.6501
# Epoch 47/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9907 - accuracy: 0.6271
# Epoch 47: val_accuracy did not improve from 0.65014
# 359/359 [==============================] - 37s 103ms/step - loss: 0.9907 - accuracy: 0.6271 - val_loss: 0.9557 - val_accuracy: 0.6369
# Epoch 48/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9855 - accuracy: 0.6339
# Epoch 48: val_accuracy did not improve from 0.65014
# 359/359 [==============================] - 39s 109ms/step - loss: 0.9855 - accuracy: 0.6339 - val_loss: 0.9746 - val_accuracy: 0.6348
# Epoch 49/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9832 - accuracy: 0.6322
# Epoch 49: val_accuracy improved from 0.65014 to 0.66201, saving model to model_weights.weights.h5
# 359/359 [==============================] - 42s 117ms/step - loss: 0.9832 - accuracy: 0.6322 - val_loss: 0.9189 - val_accuracy: 0.6620
# Epoch 50/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9718 - accuracy: 0.6361
# Epoch 50: val_accuracy did not improve from 0.66201
# 359/359 [==============================] - 39s 110ms/step - loss: 0.9718 - accuracy: 0.6361 - val_loss: 0.9437 - val_accuracy: 0.6459

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Training and validation loss curves

# %%
import matplotlib.pyplot as plt

# Plot the train and validation loss
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Training and validation accuracy curves

# %%
# Plot the train and validation accuracy
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, train_acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
import seaborn as sns 
import numpy as np
from sklearn.metrics import confusion_matrix

# Get the true labels and predicted labels for the validation set
validation_labels = validation_generator.classes
validation_pred_probs = model.predict(validation_generator)
validation_pred_labels = np.argmax(validation_pred_probs, axis=1)

# Compute the confusion matrix
confusion_mtx = confusion_matrix(validation_labels, validation_pred_labels)
class_names = list(train_generator.class_indices.keys())
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu', 
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 23/23 [==============================] - 1s 36ms/step
